# %% [markdown]
# # Practice 1.1
#
# # No.1
#
# Diketahui tinggi badan siswa kelas A adalah 100,5 ; 99,7 ; 101 ; 101,3 ; 99,9 ; 98,9 ; 165 ; 102,2 ; 98,7 ; 102,9 ; dan 100. Menggunakan Mean, Median, dan Modus, coba gambarkan pusat distribusi data berikut. Manakah yang paling bagus?
#
# # A. Mean
#
# Mencari mean dari dataset tinggi badan siswa kelas A

# %%
# Inisialisasi dataset
data = [100.5, 99.7, 101, 101.3, 99.9, 98.9, 165, 102.2, 98.7, 102.9, 100]
print(f"Data: {data}")

# Jumlah nilai dalam dataset 
jumlah_tinggi = sum(data)
print(f"Jumlah tinggi: {jumlah_tinggi}")

# Jumlah total data dalam dataset 
banyak_data = len(data)
print(f"Banyak data: {banyak_data}")

# Jumlah semua nilai dalam dataset 
mean_value = jumlah_tinggi / banyak_data
print(f"Mean: {mean_value}")
# Out:
# Data: [100.5, 99.7, 101, 101.3, 99.9, 98.9, 165, 102.2, 98.7, 102.9, 100]
# Jumlah tinggi: 1170.1000000000001
# Banyak data: 11
# Mean: 106.37272727272729

# %% [markdown]
# Divisualisasikan dengan histogram, maka Mean akan terlihat sebagai berikut:

# %%
import matplotlib.pyplot as plt

# Create a histogram
plt.hist(data, bins=30, edgecolor='black', alpha=0.5, color='purple')

# Add a vertical line at the mean
plt.axvline(x=mean_value, color='red', linestyle='dashed', linewidth=1, label=f'Mean = {mean_value:.2f}')

# Add labels and title
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Mean')

# Add legend
plt.legend()

# Show the plot
plt.show()

# %%
# Inisialisasi dataset
data = [100.5, 99.7, 101, 101.3, 99.9, 98.9, 165, 102.2, 98.7, 102.9, 100]
print(f"Data: {data}")

# Jumlah tinggi dalam dataset 
jumlah_tinggi = sum(data)
print(f"Jumlah tinggi: {jumlah_tinggi}")

# banyak data dalam dataset 
banyak_data = len(data)
print(f"Banyak data: {banyak_data}")

# Jumlah semua nilai dalam dataset 
mean_value = jumlah_tinggi / banyak_data
print(f"Mean: {mean_value}")
# Out:
# Data: [100.5, 99.7, 101, 101.3, 99.9, 98.9, 165, 102.2, 98.7, 102.9, 100]
# Jumlah tinggi: 1170.1000000000001
# Banyak data: 11
# Mean: 106.37272727272729

# %% [markdown]
# Divisualisasikan dengan histogram, maka Mean akan terlihat sebagai berikut:

# %%
import matplotlib.pyplot as plt

# Create a histogram
plt.hist(data, bins=30, edgecolor='black', alpha=0.5, color='purple')

# Add a vertical line at the mean
plt.axvline(x=mean_value, color='red', linestyle='dashed', linewidth=1, label=f'Mean = {mean_value:.2f}')

# Add labels and title
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Mean')

# Add legend
plt.legend()

# Show the plot
plt.show()

# %% [markdown]
# # B. Median
#
# Mencari median dari dataset tinggi badan siswa kelas A

# %%
# Inisialisasi dataset
data = [100.5, 99.7, 101, 101.3, 99.9, 98.9, 165, 102.2, 98.7, 102.9, 100]
print(f"Data: {data}")

# Mengurutkan data dari terkecil hingga terbesar
urutan = sorted(data)
print(f"Urutan data: {urutan}")

# Jumlah total data dalam dataset 
n = len(urutan)
print(f"Banyak data: {n}")

index_tengah = n//2 # double slash // is used for floor division

# Jika data berjumlah genap, median adalah rata-rata dari dua nilai tengah 
if n % 2 == 0:
    print(f"Data berjumlah Genap")
    median1 = urutan[index_tengah]
    median2 = urutan[index_tengah - 1]
    print(f"Nilai tengah: {median1} {median2}")
    median_value = (median1 + median2) / 2
    
# Jika data berjumlah ganjil, median adalah nilai tengah
else:
    print(f"Data berjumlah Ganjil")
    median_value = urutan[index_tengah]
    print(f"Nilai tengah: {median_value}")

print(f"Median: {median_value}")
# Out:
# Data: [100.5, 99.7, 101, 101.3, 99.9, 98.9, 165, 102.2, 98.7, 102.9, 100]
# Urutan data: [98.7, 98.9, 99.7, 99.9, 100, 100.5, 101, 101.3, 102.2, 102.9, 165]
# Banyak data: 11
# Data berjumlah Ganjil
# Nilai tengah: 100.5
# Median: 100.5

# %% [markdown]
# Divisualisasikan dengan histogram, maka Median akan terlihat sebagai berikut:

# %%
import matplotlib.pyplot as plt

# Create a histogram
plt.hist(data, bins=30, edgecolor='black', alpha=0.5, color='blue')

# Add a vertical line at the mean
plt.axvline(x=median_value, color='red', linestyle='dashed', linewidth=1, label=f'Median = {median_value:.2f}')

# Add labels and title
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Median')

# Add legend
plt.legend()

# Show the plot
plt.show()

# %% [markdown]
# # C. Modus
#
# Mencari modus dari dataset tinggi badan siswa kelas A

# %%
# Import library Counter untuk menghitung modus
from collections import Counter

# Inisialisasi dataset
data = [100.5, 99.7, 101, 101.3, 99.9, 98.9, 165, 102.2, 98.7, 102.9, 100]
print(f"Data: {data}")

counter = Counter(data)
mode_data = dict(counter) # ubah ke tipe data dictionary
max_counter = max(list(counter.values())) # mencari data yang memiliki counter paling banyak
print(f"Max Muncul: {max_counter}")

mode_value = []
for k, v in mode_data.items():
    print(f"{k} muncul {v}x")
    if v == max(list(counter.values())):
        mode_value.append(k)
    
print(f"Modus: {mode_value}")
# Out:
# Data: [100.5, 99.7, 101, 101.3, 99.9, 98.9, 165, 102.2, 98.7, 102.9, 100]
# Max Muncul: 1
# 100.5 muncul 1x
# 99.7 muncul 1x
# 101 muncul 1x
# 101.3 muncul 1x
# 99.9 muncul 1x
# 98.9 muncul 1x
# 165 muncul 1x
# 102.2 muncul 1x
# 98.7 muncul 1x
# 102.9 muncul 1x
# 100 muncul 1x
# Modus: [100.5, 99.7, 101, 101.3, 99.9, 98.9, 165, 102.2, 98.7, 102.9, 100]

# %% [markdown]
# Divisualisasikan dengan histogram, maka Modus akan terlihat sebagai berikut:

# %%
import matplotlib.pyplot as plt

# Create a histogram
plt.hist(data, bins=30, edgecolor='black', alpha=0.5, color='green')

# Add a vertical line at the mean
plt.axvline(x=mode_value[0], color='red', linestyle='dashed', linewidth=1, label=f'Modus 1 = {mode_value[0]:.2f}')
plt.axvline(x=mode_value[1], color='blue', linestyle='dashed', linewidth=1, label=f'Modus 2 = {mode_value[1]:.2f}')
plt.axvline(x=mode_value[2], color='aqua', linestyle='dashed', linewidth=1, label=f'Modus 3 = {mode_value[2]:.2f}')
plt.axvline(x=mode_value[3], color='grey', linestyle='dashed', linewidth=1, label=f'Modus 4 = {mode_value[3]:.2f}')
plt.axvline(x=mode_value[4], color='yellow', linestyle='dashed', linewidth=1, label=f'Modus 5 = {mode_value[4]:.2f}')
plt.axvline(x=mode_value[5], color='silver', linestyle='dashed', linewidth=1, label=f'Modus 6 = {mode_value[5]:.2f}')
plt.axvline(x=mode_value[6], color='olive', linestyle='dashed', linewidth=1, label=f'Modus 7 = {mode_value[6]:.2f}')
plt.axvline(x=mode_value[7], color='brown', linestyle='dashed', linewidth=1, label=f'Modus 8 = {mode_value[7]:.2f}')
plt.axvline(x=mode_value[8], color='orange', linestyle='dashed', linewidth=1, label=f'Modus 9 = {mode_value[8]:.2f}')
plt.axvline(x=mode_value[9], color='purple', linestyle='dashed', linewidth=1, label=f'Modus 10 = {mode_value[9]:.2f}')
plt.axvline(x=mode_value[10], color='pink', linestyle='dashed', linewidth=1, label=f'Modus 11 = {mode_value[10]:.2f}')


# Add labels and title
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Modus')

# Add legend
plt.legend()

# Show the plot
plt.show()

# %% [markdown]
# Median adalah yang paling baik untuk menggambarkan pusat distribusi data. Hal ini karena Median tidak terpengaruh oleh nilai-nilai ekstrem seperti Mean, dan Median juga dapat memberikan gambaran yang lebih baik tentang bagaimana data terdistribusi.

# %% [markdown]
# # No.2
#
# Berikut adalah nilai UAS pada mata pelajaran matematika di kelas A: 95, 35, 50, 65, 70, 85, 25, 100, 80, 90, 45, 40, 35, 20, 75, 50, 40, 60, 80, 75. Menggunakan Mean, Median, dan Modus, coba gambarkan pusat distribusi data berikut. Manakah yang paling bagus?
#
# # A. Mean
#
# Mencari mean dari dataset nilai UAS matematika

# %%
# Inisialisasi dataset
data = [95, 35, 50, 65, 70, 85, 25, 100, 80, 90, 45, 40, 35, 20, 75, 50, 40, 60, 80, 75]
print(f"Data: {data}")

# Jumlah nilai dalam dataset 
jumlah_nilai = sum(data)
print(f"Jumlah nilai: {jumlah_nilai}")

# banyak data dalam dataset 
banyak_data = len(data)
print(f"Banyak data: {banyak_data}")

# Jumlah semua nilai dalam dataset 
mean_value = jumlah_nilai / banyak_data
print(f"Mean: {mean_value}")
# Out:
# Data: [95, 35, 50, 65, 70, 85, 25, 100, 80, 90, 45, 40, 35, 20, 75, 50, 40, 60, 80, 75]
# Jumlah nilai: 1215
# Banyak data: 20
# Mean: 60.75

# %% [markdown]
# Divisualisasikan dengan histogram, maka Mean akan terlihat sebagai berikut:

# %%
import matplotlib.pyplot as plt

# Create a histogram
plt.hist(data, bins=30, edgecolor='black', alpha=0.5, color='purple')

# Add a vertical line at the mean
plt.axvline(x=mean_value, color='red', linestyle='dashed', linewidth=1, label=f'Mean = {mean_value:.2f}')

# Add labels and title
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Mean')

# Add legend
plt.legend()

# Show the plot
plt.show()

# %% [markdown]
# # B. Median
#
# Mencari median dari dataset nilai UAS matematika

# %%
# Inisialisasi dataset
data = [95, 35, 50, 65, 70, 85, 25, 100, 80, 90, 45, 40, 35, 20, 75, 50, 40, 60, 80, 75]
print(f"Data: {data}")

# Mengurutkan data dari terkecil hingga terbesar
urutan = sorted(data)
print(f"Urutan data: {urutan}")

# Jumlah total data dalam dataset 
n = len(urutan)
print(f"Banyak data: {n}")

index_tengah = n//2 # double slash // is used for floor division

# Jika data berjumlah genap, median adalah rata-rata dari dua nilai tengah 
if n % 2 == 0:
    print(f"Data berjumlah Genap")
    median1 = urutan[index_tengah]
    median2 = urutan[index_tengah - 1]
    print(f"Nilai tengah: {median1} {median2}")
    median_value = (median1 + median2) / 2
    
# Jika data berjumlah ganjil, median adalah nilai tengah
else:
    print(f"Data Ganjil")
    median_value = urutan[index_tengah]
    print(f"Nilai tengah: {median_value}")

print(f"Median: {median_value}")
# Out:
# Data: [95, 35, 50, 65, 70, 85, 25, 100, 80, 90, 45, 40, 35, 20, 75, 50, 40, 60, 80, 75]
# Urutan data: [20, 25, 35, 35, 40, 40, 45, 50, 50, 60, 65, 70, 75, 75, 80, 80, 85, 90, 95, 100]
# Banyak data: 20
# Data berjumlah Genap
# Nilai tengah: 65 60
# Median: 62.5

# %% [markdown]
# Divisualisasikan dengan histogram, maka Median akan terlihat sebagai berikut:

# %%
import matplotlib.pyplot as plt

# Create a histogram
plt.hist(data, bins=30, edgecolor='black', alpha=0.5, color='blue')

# Add a vertical line at the mean
plt.axvline(x=median_value, color='red', linestyle='dashed', linewidth=1, label=f'Median = {median_value:.2f}')

# Add labels and title
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Median')

# Add legend
plt.legend()

# Show the plot
plt.show()

# %% [markdown]
# # C. Modus
#
# Mencari modus dari dataset nilai UAS matematika

# %%
# Import library Counter untuk menghitung modus
from collections import Counter

# Inisialisasi dataset
data = [95, 35, 50, 65, 70, 85, 25, 100, 80, 90, 45, 40, 35, 20, 75, 50, 40, 60, 80, 75]
print(f"Data: {data}")

counter = Counter(data)
mode_data = dict(counter) # ubah ke tipe data dictionary
max_counter = max(list(counter.values())) # mencari data yang memiliki counter paling banyak
print(f"Max Muncul: {max_counter}")

mode_value = []
for k, v in mode_data.items():
    print(f"{k} muncul {v}x")
    if v == max(list(counter.values())):
        mode_value.append(k)
    
print(f"Modus: {mode_value}")
# Out:
# Data: [95, 35, 50, 65, 70, 85, 25, 100, 80, 90, 45, 40, 35, 20, 75, 50, 40, 60, 80, 75]
# Max Muncul: 2
# 95 muncul 1x
# 35 muncul 2x
# 50 muncul 2x
# 65 muncul 1x
# 70 muncul 1x
# 85 muncul 1x
# 25 muncul 1x
# 100 muncul 1x
# 80 muncul 2x
# 90 muncul 1x
# 45 muncul 1x
# 40 muncul 2x
# 20 muncul 1x
# 75 muncul 2x
# 60 muncul 1x
# Modus: [35, 50, 80, 40, 75]

# %% [markdown]
# Divisualisasikan dengan histogram, maka Modus akan terlihat sebagai berikut:

# %%
import matplotlib.pyplot as plt

# Create a histogram
plt.hist(data, bins=30, edgecolor='black', alpha=0.5, color='green')

# Add a vertical line at the mean
plt.axvline(x=mode_value[0], color='red', linestyle='dashed', linewidth=1, label=f'Modus 1 = {mode_value[0]:.2f}')
plt.axvline(x=mode_value[1], color='blue', linestyle='dashed', linewidth=1, label=f'Modus 2 = {mode_value[1]:.2f}')
plt.axvline(x=mode_value[2], color='aqua', linestyle='dashed', linewidth=1, label=f'Modus 3 = {mode_value[2]:.2f}')
plt.axvline(x=mode_value[3], color='grey', linestyle='dashed', linewidth=1, label=f'Modus 4 = {mode_value[3]:.2f}')
plt.axvline(x=mode_value[4], color='yellow', linestyle='dashed', linewidth=1, label=f'Modus 5 = {mode_value[4]:.2f}')

# Add labels and title
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Modus')

# Add legend
plt.legend()

# Show the plot
plt.show()

# %% [markdown]
# Median adalah ukuran pemusatan data yang paling baik karena tidak terpengaruh oleh nilai ekstrem seperti Mean dan lebih representatif daripada Modus.
